# %%
## House Price Prediction Example

# %%
import pandas as pd

# %%
df = pd.read_csv(r"data\house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
important_features = ['price','bedrooms','bathrooms','floors','waterfront','grade','lat','long']
data = df[important_features]

# %%
data.head()
# Out:
#       price  bedrooms  bathrooms  floors  waterfront  grade      lat     long
# 0  221900.0         3       1.00     1.0           0      7  47.5112 -122.257
# 1  538000.0         3       2.25     2.0           0      7  47.7210 -122.319
# 2  180000.0         2       1.00     1.0           0      6  47.7379 -122.233
# 3  604000.0         4       3.00     1.0           0      7  47.5208 -122.393
# 4  510000.0         3       2.00     1.0           0      8  47.6168 -122.045

# %%
data.describe()
# Out:
#               price      bedrooms     bathrooms        floors    waterfront  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   5.400881e+05      3.370842      2.114757      1.494309      0.007542
# std    3.671272e+05      0.930062      0.770163      0.539989      0.086517
# min    7.500000e+04      0.000000      0.000000      1.000000      0.000000
# 25%    3.219500e+05      3.000000      1.750000      1.000000      0.000000
# 50%    4.500000e+05      3.000000      2.250000      1.500000      0.000000
# 75%    6.450000e+05      4.000000      2.500000      2.000000      0.000000
# max    7.700000e+06     33.000000      8.000000      3.500000      1.000000
#
#               grade           lat          long
# count  21613.000000  21613.000000  21613.000000
# mean       7.656873     47.560053   -122.213896
# std        1.175459      0.138564      0.140828
# min        1.000000     47.155900   -122.519000
# ...

# %%
#Chick pre-processing
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 8 columns):
# price         21613 non-null float64
# bedrooms      21613 non-null int64
# bathrooms     21613 non-null float64
# floors        21613 non-null float64
# waterfront    21613 non-null int64
# grade         21613 non-null int64
# lat           21613 non-null float64
# long          21613 non-null float64
# dtypes: float64(5), int64(3)
# memory usage: 1.3 MB

# %%
X = data.iloc[:, 1:].values
Y = data.iloc[:, 0].values

# %%
X
# Out:
# array([[   3.    ,    1.    ,    1.    , ...,    7.    ,   47.5112,
#         -122.257 ],
#        [   3.    ,    2.25  ,    2.    , ...,    7.    ,   47.721 ,
#         -122.319 ],
#        [   2.    ,    1.    ,    1.    , ...,    6.    ,   47.7379,
#         -122.233 ],
#        ...,
#        [   2.    ,    0.75  ,    2.    , ...,    7.    ,   47.5944,
#         -122.299 ],
#        [   3.    ,    2.5   ,    2.    , ...,    8.    ,   47.5345,
#         -122.069 ],
#        [   2.    ,    0.75  ,    2.    , ...,    7.    ,   47.5941,
#         -122.299 ]])

# %%
Y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\Reda\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3)

# %%
x_train
# Out:
# array([[   3.    ,    1.75  ,    1.5   , ...,    7.    ,   47.6988,
#         -122.32  ],
#        [   3.    ,    1.75  ,    1.    , ...,    7.    ,   47.6978,
#         -122.316 ],
#        [   6.    ,    3.25  ,    2.    , ...,    8.    ,   47.6464,
#         -122.401 ],
#        ...,
#        [   2.    ,    1.    ,    1.    , ...,    6.    ,   47.4989,
#         -122.317 ],
#        [   3.    ,    1.    ,    1.    , ...,    7.    ,   47.6706,
#         -122.268 ],
#        [   3.    ,    2.    ,    1.    , ...,    8.    ,   47.6227,
#         -122.207 ]])

# %%
x_test
# Out:
# array([[   4.    ,    2.5   ,    2.    , ...,    9.    ,   47.384 ,
#         -122.149 ],
#        [   3.    ,    1.    ,    1.    , ...,    6.    ,   47.5291,
#         -122.356 ],
#        [   3.    ,    1.5   ,    1.    , ...,    7.    ,   47.7126,
#         -122.211 ],
#        ...,
#        [   2.    ,    1.5   ,    2.    , ...,    7.    ,   47.7178,
#         -122.19  ],
#        [   3.    ,    2.5   ,    2.    , ...,    8.    ,   47.3494,
#         -122.301 ],
#        [   3.    ,    2.25  ,    3.    , ...,    7.    ,   47.7052,
#         -122.346 ]])

# %%
y_train
# Out:
# array([ 536000.,  575700.,  696000., ...,  209000.,  525000., 1190000.])

# %%
y_test
# Out:
# array([330000., 342000., 370000., ..., 289000., 335000., 280000.])

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

print("b = ", lin_reg.intercept_)
print("a = ", lin_reg.coef_)
# Out:
# b =  -55547113.795065634
# a =  [  21625.73808851   80011.23618555  -65025.8495003   870333.50748442
#   171672.9630933   633002.15499634 -200597.55916797]

# %%
y_predicted = lin_reg.predict(x_test)

# %%
y_predicted
# Out:
# array([651387.58374576, 193124.25903706, 491872.08958561, ...,
#        404299.56446026, 466677.83699461, 444225.27226488])

# %%
#Specify the House features your self:

# %%
your_predicted = lin_reg.predict([[4, 2, 1, 0, 7, 47.7379, -122.257]])
your_predicted
# Out:
# array([578745.88801003])

# %%
#select rows whose column value equals a scalar

# %%
data.loc[df['price'] == 1275000]

# %%
#To select rows whose column value is in an iterable

# %%
data.loc[df['bedrooms'].isin([6])]
